# %% [markdown]
# Bài 1: Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ
# nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.

# %%
lst= list(map(int, input().split()))
delta=[]
for i in lst:
    if i not in delta:
        delta.append(i)
print(delta)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Bài 2: Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị
# trí i), giữ nguyên thứ tự

# %%
lst= list(map(int,input().split()))
delta=[0]
for i in range(len(lst)):
    delta.append(int(lst[i]) + int(delta[-1]))
print(delta[1::])
# Out:
# [10, 5, 15]

# %% [markdown]
# Bài 3: Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %% [markdown]
# Bài 4: Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp
# lại, thêm vào list của key đó

# %%
n = input().split()
result_dict = {}

for items in n:
    key, value = items.split(':')
    if key not in result_dict:
        result_dict[key] = [value] 
    else:
        result_dict[key].append(value)

print(result_dict)
# Out:
# {'a': ['2', '3'], 'b': ['1'], 'c': ['2']}

# %% [markdown]
# Bài 5: Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros':
# ...} (đếm số >0, <0, =0)

# %%
lst= list(map(int, input().split()))
dict={
    'positives': 0,
    'negatives': 0,
    'zeros': 0
}
for i in lst:
    if i <0:
        dict['negatives'] +=1
    elif i>0:
        dict['positives'] +=1
    else:
        dict['zeros'] +=1
print(dict)
# Out:
# {'positives': 3, 'negatives': 3, 'zeros': 3}

# %% [markdown]
# Bài 6: Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số
# trong list đó.

# %%
x= list(map(int, input().split()))
dem=0
for i in x:
    dem+= int(i)
print(dem)
# Out:
# 10

# %% [markdown]
# Bài 7: Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo
# ngược

# %%
t= tuple(map(int,input().split()))
first=t[0]
last =t[-1]
reversed_t=t[::-1]
print(first,last,reversed_t)

# %% [markdown]
# Bài 8: Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng
# chuỗi và lưu vào dictionary.

# %%
lst= list(input().split())
dict={}
for items in lst:
    if items not in dict:
        dict[items] =1
    else:
        dict[items] +=1
print(dict)
# Out:
# {'a': 3, 'b': 1, 'c': 1, 'd': 1, 'e': 1}

# %% [markdown]
# Bài 9: Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới
# trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có
# trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của
# key

# %%
dict1= dict(input())
print(dict1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 dict1= dict(input())
#       2 print(dict1)
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# Bài 10: Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra
# list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple
# có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của
# số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên
# trong tuple.

# %%
a= list(map(int,input().split()))
k=int(input())
result=[]
for i in range(len(a)):
    for j in range(i+1, len(a)):
        if a[i] + a[j] ==k:
            result.append(a[i], a[j])
result.sort()
print(result)

# %% [markdown]
# Bài 11: [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
x= map(int,input().split())
t_1=[]
t_2=[]
for i in list(x):
    if i %2==0:
        t_1.append(i)
    else:
        t_2.append(i)
print(tuple(t_1), tuple(t_2), sep='\n')

# %% [markdown]
# Bài 12: [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list.
# Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất
# trong số đó.

# %%
lst= list(map(int, input().split()))
dict={}
for i in lst:
    if i not in dict:
        dict[i]= 1
    else:
        dict[i] +=1

count= max(dict.values())
candidates=[]
for k,v in dict.items(): #dict.items gọi (key,value) trong dict
    if v== count:
        candidates.append(k)

print(min(candidates))
# Out:
# 5

# %% [markdown]
# Bài 13: [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một
# dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In
# ra dictionary mới.

# %%
lst= list(input().split())
keys=[]
values=[]
dict={}
for i in range(0,len(lst),2):
   keys.append(lst[i])
   values.append(lst[i+1])
for e in range(len(keys)):
   dict[values[e]] = keys[e]
print(dict)
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
lst= list(input().split())
dict={}
for i in range(0,len(lst),2):
    dict[lst[i+1]] = lst[i]
print(dict)
# Out:
# {'A-1': 'code', 'B-2': 'user'}

# %% [markdown]
# Bài 14: [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
lst_1=list(map(int, input().split()))
lst_2=list(map(int, input().split()))
lst=[]
for i in lst_1:
    for e in lst_2:
        if i ==e:
            if i not in lst:
                lst.append(i)
            else:
                continue
print(lst)
# Out:
# [10, 20, 30]

# %% [markdown]
# bài 15: Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp keyvalue từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
lst= list(input().split())
m= int(input())
dict1={}
dict2={}
for i in range(0,len(lst),2):
    dict1[lst[i]] = lst[i+1]
for k,v in dict1.items():
    if int(v) > m:
        dict2[k]=v
print(dict2)
# Out:
# {'x': '-5', 'z': '-2'}
